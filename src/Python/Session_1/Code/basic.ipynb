# %%
a = {1, 2, 3, 4}
b = {3, 4, 5}

print (a - b)                 # {1, 2} (in A, not in B)

print (b - a)                 # {5} (in B, not in A)

print (a.difference (b))
# Out:
# {1, 2}
# {5}
# {1, 2}
