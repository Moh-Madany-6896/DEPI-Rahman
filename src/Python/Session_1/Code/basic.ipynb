# %%
# list_1 = [1, 2, 3, 4, "amit", "learning", True, [1, 2, 3, "true", ["ml", "dl", "ds"]]]
list_1 = [1, 2, 3, 4, "amit", "learning", True]

list_2 = [2, 5, "546"]


item = input ("Enter Your item")

print (list_2)
print (item)
print ("##############")

list_2.insert (0, item)

list_2
# Out:
# [2, 5, '546']
# Mohamed
# ##############
# ['Mohamed', 2, 5, '546']
