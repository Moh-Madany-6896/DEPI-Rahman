# %%
print ("Hello")
# Out:
# Hello

# %%
name = "mohamed ahmed"
age = 29
course = "DE"
id = 13454
# print ("my name is", name, "and my age is", age, "I'm studing the course", course, "My ID is", id)
# print ("my name is {} and my age is {} I'm studing the course {} My ID is {}".format(name, age, course, id))
# print (f"my name is {name} and my age is {age} I'm studing the course {course} My ID is {id}")

name.title()
# Out:
# 'Mohamed Ahmed'

# %% [markdown]
# hi
# # Mohamed
# - 29 years
